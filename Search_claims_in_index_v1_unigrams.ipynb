# %%
import os
import io
from zipfile import ZipFile

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import shutil
import csv

# %%
import re
import xapian
import pandas as pd
import numpy as np

# %%
pd.options.display.max_colwidth = 100

# %%
dbpath = "full_index"
SEARCH_RESULT_PATH = "data/search_results_v1.csv"
SOURCES = ['dev', 'train', 'test']

# %%
# !xapian-delve $dbpath
# Out:
# UUID = b940719a-3fb5-4d57-8b01-3186790b1ade
# number of documents = 3833466
# average document length = 170.939
# document length lower bound = 1
# document length upper bound = 31154
# highest document id ever used = 3833466
# has positional information = true
# revision = 392
# currently open for writing = false

# %%
# !xapian-delve -r 1833129 -d $dbpath
# Out:
# Data for record #1833129:
#
# Term List for record #1833129: 17 2004 2007 3 QKim_Hyde Skim_hyde ZSkim_hyd Za Zand Zappear Zaustralian Zaway Zby Zcharact Zchris Zdepart Zfebruari Zfiction Zfirst Zfrom Zhe Zhemsworth Zhis Zhome Zhyde Zjonathan Zjuli Zkim Zkimber Zmade Zon Zopera Zplay Zscreen Zsoap Zthe Zwas a and appearance australian away by character chris departed february fictional first from he hemsworth his home hyde jonathan july kim kimberly made on opera played screen soap the was

# %% [markdown]
# # Retrieve documents relevant to claims

# %%
def get_doc_id(match):
    for term in match.document.termlist():
        term = term.term.decode("utf-8") 
        m = re.match("Q(.*)", term)
        if m:
            return m[1]
    return None

# %%
# Prepare enquiry object

# Open the database we're going to search.
db = xapian.Database(dbpath)

# Set up a QueryParser with a stemmer and suitable prefixes
queryparser = xapian.QueryParser()
queryparser.set_stemmer(xapian.Stem("en"))
queryparser.set_stemming_strategy(queryparser.STEM_SOME)

# Use an Enquire object on the database to run the query
enquire = xapian.Enquire(db)

# %%
claim_df = pd.read_csv('data/claims.csv', index_col='claim_id')
claim_df.head()
# Out:
#                                                       claim source
# claim_id
# 3            Chris Hemsworth appeared in A Perfect Getaway.  train
# 4         Chris Hemsworth disappeared in A Perfect Getaway.  train
# 6                                Firefox is an application.   test
# 7                                   Roald Dahl is a writer.  train
# 8                                 Roald Dahl is a governor.  train

# %%
claim_df.shape
# Out:
# (165447, 2)

# %%
# %%time
fields = ['claim_id', 'found_doc', 'rank', 'percentage', 'weight']
pagesize = 100
i = 0
results = []

with open(search_results_path, 'w') as csvFile:
    writer = csv.DictWriter(csvFile, fieldnames=fields)
    writer.writeheader()

    for claim_id, claim in claim_df.claim.items():
        if i % 100 == 0:
            print(i // 100, claim_id)
        i += 1

        query = queryparser.parse_query(claim)
        enquire.set_query(query)
        matches = enquire.get_mset(0, pagesize)

        query_results = []
        for match in matches:
            result = dict(
                claim_id = claim_id,
                found_doc = get_doc_id(match),
                rank = match.rank + 1,
                percentage = match.percent,
                weight = match.weight,            
            )
            query_results.append(result)
        writer.writerows(query_results)
        results += query_results
csvFile.close()
# Out:
# 0 3
# 1 131
# 2 266
# 3 389
# 4 540
# 5 684
# 6 836
# 7 957
# 8 1102
# 9 1258
# 10 1395
# 11 1531
# 12 1670
# 13 1806
# 14 1934
# 15 2073
# 16 2205
# 17 2340
# 1653 229282
# 1654 229401
# CPU times: user 4h 7min 7s, sys: 40min 40s, total: 4h 47min 48s
# Wall time: 5h 7min 33s

# %% [markdown]
# # Analyse Found Documents

# %% [markdown]
# ## Read search results

# %%
import unicodedata

# %%
results_df = pd.read_csv(SEARCH_RESULT_PATH)

# %%
normalise = lambda item: unicodedata.normalize('NFD', item) if isinstance(item, str) else item
results_df['found_doc'] = results_df['found_doc'].apply(normalise)

results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14965679 entries, 0 to 14965678
# Data columns (total 5 columns):
# claim_id      int64
# found_doc     object
# rank          int64
# percentage    int64
# weight        float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 570.9+ MB

# %%
#results_df.sort_values('percentage', ascending=False).head(100)
results_df.sort_values('weight', ascending=False).head(10)
# Out:
#           claim_id                found_doc  rank  percentage      weight
# 11747008    179663        Michael_Giacchino     1         100  305.577922
# 11744008    179614        Michael_Giacchino     1         100  305.577922
# 11744208    179617        Michael_Giacchino     1         100  305.577922
# 11744908    179627        Michael_Giacchino     1         100  305.577922
# 12909714    199112  International_relations     1         100  286.608265
# 12902114    199004  International_relations     1         100  286.608265
# 12903014    199019  International_relations     1         100  286.608265
# 12903814    199030  International_relations     1         100  286.608265
# 12906614    199065  International_relations     1         100  286.608265
# 12901514    198993  International_relations     1         100  286.608265

# %% [markdown]
# ## Read claims

# %%
sources = SOURCES
if 'test' in sources:
    sources.remove('test')
    
labelled_claims_df = pd.read_json('data/l_claims.json').sort_index()
mask = labelled_claims_df.source.isin(sources)
labelled_claims_df = labelled_claims_df[mask]

labelled_claims_df.head()
# Out:
#                                                claim                evidence  \
# 3     Chris Hemsworth appeared in A Perfect Getaway.  [[Chris_Hemsworth, 2]]
# 4  Chris Hemsworth disappeared in A Perfect Getaway.                      []
# 7                            Roald Dahl is a writer.       [[Roald_Dahl, 0]]
# 8                          Roald Dahl is a governor.       [[Roald_Dahl, 0]]
# 9        Ireland has relatively low-lying mountains.         [[Ireland, 10]]
#
#              label source      evidence_docs  evidence_doc_count  \
# 3         SUPPORTS  train  [Chris_Hemsworth]                   1
# 4  NOT ENOUGH INFO  train                 []                   0
# 7         SUPPORTS  train       [Roald_Dahl]                   1
# 8          REFUTES  train       [Roald_Dahl]                   1
# 9         SUPPORTS  train          [Ireland]                   1
#
#    evidence_sentence_count     evidence_set_str
# 3                        1  {'Chris_Hemsworth'}
# 4                        0                set()
# 7                        1       {'Roald_Dahl'}
# 8                        1       {'Roald_Dahl'}
# 9                        1          {'Ireland'}

# %% [markdown]
# ## Estimate index-search performance

# %%
# %%time

results = []
for top in range(5, 101, 5):
    #print(top)
    mask = results_df['rank'] <= top
    
    func = lambda x: set(x)
    found_docs_df = results_df[mask].pivot_table(index='claim_id', values='found_doc', aggfunc=func)

    recall_df = labelled_claims_df[['evidence_docs', 'source', 'claim']].join(found_docs_df)

    def func(x):
        if isinstance(x['found_doc'], set):
            return set(x['evidence_docs']).difference(x['found_doc'])
        return set(x['evidence_docs'])

    recall_df['missed_docs'] = recall_df.apply(func, axis=1)
    recall_df['missed_count'] = recall_df['missed_docs'].apply(len)

    recall_df = recall_df.pivot_table(index='missed_count', columns='source',# margins=True,
                                                    values='claim', aggfunc='count', fill_value=0)

    recall_df = (recall_df / recall_df.sum() * 100).head(1)
    recall_df['top'] = top
    results += recall_df.to_dict(orient="records")
# Out:
# CPU times: user 4min 22s, sys: 17.9 s, total: 4min 40s
# Wall time: 4min 42s

# %%
df = pd.DataFrame.from_records(results).set_index('top')
df.plot.line(title='Document Recall Rate Based on Top')
plt.show()
df
# Out:
#              dev      train
# top
# 5.0    65.606879  56.729163
# 10.0   71.085783  63.612675
# 15.0   73.885223  67.321879
# 20.0   75.924815  69.680094
# 25.0   77.084583  71.471787
# 30.0   78.164367  72.947219
# 35.0   79.104179  74.204704
# 40.0   80.063987  75.178929
# 45.0   80.723855  76.108464
# 50.0   81.343731  76.836554
# 55.0   81.823635  77.476641
# 60.0   82.163567  78.014287
# 65.0   82.583483  78.520994
# 70.0   83.023395  78.973386
# 75.0   83.523295  79.403777
# 80.0   83.843231  79.770916
# 85.0   83.983203  80.105054
# 90.0   84.223155  80.496256
# 95.0   84.523095  80.778142
# 100.0  84.803039  81.075841

# %%
# %%time

results = []
for top in range(5, 101, 5):
    #print(top)
    mask = results_df['percentage'] >= top
    
    func = lambda x: set(x)
    found_docs_df = results_df[mask].pivot_table(index='claim_id', values='found_doc', aggfunc=func)

    recall_df = labelled_claims_df[['evidence_docs', 'source', 'claim']].join(found_docs_df)

    def func(x):
        if isinstance(x['found_doc'], set):
            return set(x['evidence_docs']).difference(x['found_doc'])
        return set(x['evidence_docs'])

    recall_df['missed_docs'] = recall_df.apply(func, axis=1)
    recall_df['missed_count'] = recall_df['missed_docs'].apply(len)

    recall_df = recall_df.pivot_table(index='missed_count', columns='source',# margins=True,
                                                    values='claim', aggfunc='count', fill_value=0)

    recall_df = (recall_df / recall_df.sum() * 100).head(1)
    recall_df['percentage'] = top
    results += recall_df.to_dict(orient="records")
# Out:
# CPU times: user 3min 56s, sys: 14.8 s, total: 4min 11s
# Wall time: 4min 12s

# %%
df = pd.DataFrame.from_records(results).set_index('percentage')
df.plot.line(title='Document Recall Rate Based on Percentage')
plt.show()
df
# Out:
#                   dev      train
# percentage
# 5.0         84.803039  81.075841
# 10.0        84.803039  81.075153
# 15.0        84.803039  81.071716
# 20.0        84.763047  81.032527
# 25.0        84.583083  80.941773
# 30.0        84.423115  80.701139
# 35.0        83.983203  80.130492
# 40.0        83.103379  79.134267
# 45.0        81.683663  77.588708
# 50.0        79.884023  75.457377
# 55.0        77.604479  72.722398
# 60.0        74.425115  69.143824
# 65.0        70.645871  64.939601
# 70.0        66.666667  60.120730
# 75.0        62.387522  54.917531
# 80.0        57.808438  49.869714
# 85.0        53.229354  44.519385
# 90.0        49.010198  40.008525
# 95.0        45.350930  36.635522
# 100.0       43.611278  34.700135

# %%
# %%time

results = []
for top in range(10, 25, 2):
    #print(top)
    mask = results_df['weight'] >= top
    
    func = lambda x: set(x)
    found_docs_df = results_df[mask].pivot_table(index='claim_id', values='found_doc', aggfunc=func)

    recall_df = labelled_claims_df[['evidence_docs', 'source', 'claim']].join(found_docs_df)

    def func(x):
        if isinstance(x['found_doc'], set):
            return set(x['evidence_docs']).difference(x['found_doc'])
        return set(x['evidence_docs'])

    recall_df['missed_docs'] = recall_df.apply(func, axis=1)
    recall_df['missed_count'] = recall_df['missed_docs'].apply(len)

    recall_df = recall_df.pivot_table(index='missed_count', columns='source',# margins=True,
                                                    values='claim', aggfunc='count', fill_value=0)

    recall_df = (recall_df / recall_df.sum() * 100).head(1)
    recall_df['weight'] = top
    results += recall_df.to_dict(orient="records")
# Out:
# CPU times: user 2min, sys: 9.92 s, total: 2min 10s
# Wall time: 2min 11s

# %%
df = pd.DataFrame.from_records(results).set_index('weight')
df.plot.line(title='Document Recall Rate Based on Weight')
plt.show()
df
# Out:
#               dev      train
# weight
# 10.0    84.763047  81.037340
# 12.0    84.323135  80.855833
# 14.0    83.723255  80.314749
# 16.0    83.163367  79.702164
# 18.0    82.443511  78.884007
# 20.0    81.763647  77.779840
# 22.0    80.143971  76.314034
# 24.0    77.384523  74.113951

# %% [markdown]
# ## Evidence found

# %%
found_df = labelled_claims_df[(labelled_claims_df.missed_count == 0) & (labelled_claims_df.label != 'NOT ENOUGH INFO')]

# %%
found_df.evidence_docs.astype(str).value_counts().to_frame()
# Out:
#                                                                                                     evidence_docs
# ['Snoop_Dogg']                                                                                                166
# ['Wyatt_Earp']                                                                                                148
# ['Marlon_Brando']                                                                                             134
# ['Miley_Cyrus']                                                                                               120
# ['Adele']                                                                                                     118
# ['David_Beckham']                                                                                             102
# ['Tim_Rice']                                                                                                  102
# ['Anne_Hathaway']                                                                                             100
# ['Carrie_Fisher']                                                                                              98
# ['Lady_Gaga']                                                                                                  94
# ['Noam_Chomsky']                                                                                               94
# ['Willie_Nelson']                                                                                              94
# ['Marilyn_Monroe']                                                                                             94
# ['Imagine_Dragons']                                                                                            92
# ['Peyton_Manning']                                                                                             91
# ['Frank_Sinatra']                                                                                              90
# ['Paul_Newman']                                                                                                90
# ['Prison_Break']                                                                                               90
# ['Dwayne_Johnson']                                                                                             90
# ['Kurt_Angle']                                                                                                 89
# ['Halle_Berry']                                                                                                89
# ['Eminem']                                                                                                     89
# ['Tom_Felton']                                                                                                 88
# ['John_Lennon']                                                                                                87
# ['United_Kingdom']                                                                                             87
# ['Jennifer_Aniston']                                                                                           87
# ['Leonardo_da_Vinci']                                                                                          87
# ['Bradley_Cooper']                                                                                             87
# ['Led_Zeppelin']                                                                                               87
# ['Jeff_Bezos']                                                                                                 86
# ...                                                                                                           ...
# ['Ningxia', 'Hui_people']                                                                                       1
# ['Star_Wars', 'Darth_Vader']                                                                                    1
# ['Anne_Frank', 'Margot_Frank']                                                                                  1
# ['Nepal', 'Shah_dynasty']                                                                                       1
# ['The_Beach_Boys', 'Bruce_Johnston']                                                                            1
# ['Peter_Andre', 'Katie_Price']                                                                                  1
# ['Travis_Scott', 'Days_Before_Rodeo']                                                                           1
# ['Odysseus', 'Homer', 'Odyssey']                                                                                1
# ['Hotell', 'Lisa_Langseth']                                                                                     1
# ['Red_Hot_Chili_Peppers', 'Blood_Sugar_Sex_Magik_Tour']                                                         1
# ['Thenmerku_Paruvakaatru', 'Seenu_Ramasamy']                                                                    1
# ['Michael_Jeter', 'The_Fisher_King']                                                                            1
# ['Aruba', 'Tundra']                                                                                             1
# ['Sheldon_Cooper', 'Jim_Parsons']                                                                               1
# ['Jesse_Eisenberg', 'Rio_2']                                                                                    1
# ['Reflektor', 'Arcade_Fire']                                                                                    1
# ['Cheaper_by_the_Dozen_2', 'Tom_Welling']                                                                       1
# ['Barranquilla', 'Shakira']                                                                                     1
# ['Mary_Marvel', 'Supergirl']                                                                                    1
# ['Haitian_Creole', 'French_language']                                                                           1
# ['Superman', 'Daily_Planet']                                                                                    1
# ['London', 'Financial_centre']                                                                                  1
# ['Hometown_Glory', 'Adele']                                                                                     1
# ['Anna_Gunn', 'Breaking_Bad', 'Skyler_White']                                                                   1
# ['The_Fearless_Vampire_Killers', 'Manson_Family', 'Doris_Tate', 'Sharon_Tate', 'Eye_of_the_Devil']              1
# ['Mogambo', 'Grace_Kelly']                                                                                      1
# ['Battle_of_Trenton', 'George_Washington', 'Siege_of_Boston']                                                   1
# ['Vito_Corleone', 'Sonny_Corleone', 'Fredo_Corleone']                                                           1
# ['Blue_whale', 'Baleen_whale']                                                                                  1
# ['Rio_de_Janeiro', 'Brazilian_Carnival']                                                                        1
#
# [4867 rows x 1 columns]

# %% [markdown]
# ## Evidence missed

# %%
missed_df = labelled_claims_df[labelled_claims_df.missed_count > 0]

# %%
missed_df.missed_docs.astype(str).value_counts().to_frame()
# Out:
#                                                                                                       missed_docs
# {'Deadpool_-LRB-film-RRB-'}                                                                                   118
# {'Planet_of_the_Apes_-LRB-1968_film-RRB-'}                                                                    114
# {'The_Prestige_-LRB-film-RRB-'}                                                                               103
# {'Glee_-LRB-TV_series-RRB-'}                                                                                  102
# {'François_de_Belleforest'}                                                                                  100
# {'AC/DC'}                                                                                                      97
# {'Eagles_-LRB-band-RRB-'}                                                                                      95
# {'United_States'}                                                                                              94
# {'Beyoncé'}                                                                                                   93
# {'O._J._Simpson'}                                                                                              90
# {'Constantine_-LRB-film-RRB-'}                                                                                 88
# {'Apple_Inc.'}                                                                                                 84
# {'Overwatch_-LRB-video_game-RRB-'}                                                                             83
# {'Star_Wars-COLON-_The_Force_Awakens'}                                                                         81
# {'Prince_-LRB-musician-RRB-'}                                                                                  80
# {'Game_of_Thrones_-LRB-season_3-RRB-'}                                                                         80
# {'Charles,_Prince_of_Wales'}                                                                                   78
# {'Outlander_-LRB-TV_series-RRB-'}                                                                              77
# {'The_Wolf_of_Wall_Street_-LRB-2013_film-RRB-'}                                                                76
# {'Dr._Dre'}                                                                                                    75
# {'Sunrise_-LRB-company-RRB-'}                                                                                  75
# {'Thor-COLON-_The_Dark_World'}                                                                                 75
# {'Furia_-LRB-film-RRB-'}                                                                                       73
# {'Penny_Dreadful_-LRB-TV_series-RRB-'}                                                                         73
# {'Blue_Velvet_-LRB-film-RRB-'}                                                                                 73
# {'Memento_-LRB-film-RRB-'}                                                                                     73
# {'Slash_-LRB-musician-RRB-'}                                                                                   72
# {'Floyd_Mayweather_Jr.'}                                                                                       71
# {'Franklin_D._Roosevelt'}                                                                                      71
# {'Citadelle_Laferrière'}                                                                                      70
# ...                                                                                                           ...
# {'FC_Barcelona', 'Copa_Eva_Duarte'}                                                                             1
# {'Prompt_book'}                                                                                                 1
# {'The_Big_Clock_-LRB-film-RRB-', 'The_Thief_-LRB-1952_film-RRB-', 'The_Lost_Weekend_-LRB-film-RRB...            1
# {'Poison_Ivy_-LRB-1992_film-RRB-', 'E.T._the_Extra-Terrestrial', 'Donnie_Darko', 'Blended_-LRB-fi...            1
# {'Monkey_Business_-LRB-1952_film-RRB-'}                                                                         1
# {'Fernando_Alonso', '1997_Formula_One_season', 'Michael_Schumacher'}                                            1
# {'Elizabeth-COLON-_The_Golden_Age', 'Elizabeth_-LRB-film-RRB-'}                                                 1
# {'Kim_Tae-yeon', "Girls'_Generation", 'Im_Yoon-ah', 'Sunny_-LRB-singer-RRB-', 'Choi_Soo-young', '...            1
# {'One_by_One_-LRB-Foo_Fighters_album-RRB-', 'Album'}                                                            1
# {'Cutout_animation'}                                                                                            1
# {'Shogun', 'Japan', 'Edo', 'China'}                                                                             1
# {'Felicity_Jones'}                                                                                              1
# {'American_Broadcasting_Company', 'Last_Man_Standing_-LRB-U.S._TV_series-RRB-', 'Home_Improvement...            1
# {'Cameron_Diaz', 'Kurt_Russell', 'Jason_Lee_-LRB-actor-RRB-'}                                                   1
# {'Lieutenant_Governor_of_California', 'Governor_of_California'}                                                 1
# {'The_Doctor_-LRB-Doctor_Who-RRB-', 'Regeneration_-LRB-Doctor_Who-RRB-'}                                        1
# {'Rastafari'}                                                                                                   1
# {'MTV', 'La_La_Anthony'}                                                                                        1
# {'App_Store_-LRB-iOS-RRB-'}                                                                                     1
# {'Mohra'}                                                                                                       1
# {'Unintended_pregnancy'}                                                                                        1
# {'Love_&_Friendship', 'Much_Ado_About_Nothing_-LRB-1993_film-RRB-', 'Emma_-LRB-1996_TV_film-RRB-'...            1
# {'Stephen_A._Douglas'}                                                                                          1
# {'Theodore_Roosevelt', 'Mount_Rushmore'}                                                                        1
# {'Robert_Redford', 'Margot_Kidder', 'Bo_Svenson', 'Susan_Sarandon', 'Edward_Herrmann'}                          1
# {'Twenty_Four_Seven_-LRB-Tina_Turner_album-RRB-'}                                                               1
# {'Blue_Moon_of_Kentucky'}                                                                                       1
# {'Liev_Schreiber', 'Lily_Rabe', 'Peter_Sarsgaard'}                                                              1
# {'Carolingian_Empire'}                                                                                          1
# {'Detroit', 'North_America', 'United_States'}                                                                   1
#
# [9416 rows x 1 columns]
