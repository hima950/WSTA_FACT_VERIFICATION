# %%
import os
import io
import json
from zipfile import ZipFile

# %%
import re
import xapian
import pandas as pd
import numpy as np

# %%
pd.options.display.max_colwidth = 150
pd.options.display.max_rows = 100

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')
stop_words = set(stopwords.words('english'))

stop_tags = ['DT', 'VB', 'VBP', 'VBD', 'VBN', 'VBZ',  'MD', 'IN', 'TO', 'PRP', 'CC',
             "(", ')', '.', ',', 'PRP$', 'VBG', 'RB', "''", "``", 'WDT', ':', 'WRB']
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vitaly/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
DUMP_FOLDER = 'data/parsed_corpus'

# %%
if (not os.path.exists('data')): os.mkdir('data')
if (not os.path.exists(DUMP_FOLDER)): os.mkdir(DUMP_FOLDER)

# %% [markdown]
# # Extract Named Entities from WIKI corpus

# %%
zf = ZipFile("../wiki-pages-text.zip")

# %%
files = [item.filename for item in zf.filelist]
len(files), files[1]
# Out:
# (110, 'wiki-pages-text/wiki-009.txt')

# %%
def read_shard(zf, path):
    items = []
    fp = zf.open(path, mode='r')
    tfp = io.TextIOWrapper(fp)
    nlines = 0
    for line in tfp.readlines():
        nlines += 1
        match = re.match("(\S+)\s(\d+)\s(.*)\n", line)
        if match:
            items.append(match.groups())
        else:
            #print(line)
            pass
    fp.close()
    tfp.close()
    return items#, nlines

# %%
def read_shard_as_df(zf, path):
    items = read_shard(zf, path)
    raw_df = pd.DataFrame(data=items, columns=['doc_id', 'sentence', 'text'])
    func = lambda x: " ".join(x)
    return raw_df.groupby('doc_id')['text'].agg(func)

# %%
# %%time
for path in sorted(files[1:]):
    print(path)
    # determine shard
    shard = ""
    m = re.match(".*wiki-(\d+).*", path)
    if m: shard = m[1]
    
    # read shart into dataframe
    items = read_shard(zf, path)
    raw_df = pd.DataFrame(data=items, columns=['page_id', 'sentence', 'text'])
    raw_df['sentence'] = raw_df.sentence.astype(int)

    raw_df.set_index(['page_id', 'sentence'], inplace=True)

    # tokenise and remove stop words
    raw_df['tokens'] = raw_df.text.apply(word_tokenize)
    raw_df['tokens'] = raw_df.tokens.apply(lambda tokens: [w for w in tokens if not w in stop_words])

    # determine parts of speech and remove stop tags
    raw_df['tagged'] = raw_df.tokens.apply(nltk.pos_tag)
    raw_df['tagged'] = raw_df.tagged.apply(lambda pairs: [(w, t) for w, t in pairs if not t in stop_tags])

    # extract keywords
    raw_df['keywords'] = raw_df.tagged.apply(lambda pairs: [w for w, t in pairs if not t in stop_tags])

    # dump keywords
    dump_path = "{}/{}.json".format(DUMP_FOLDER, shard)
    raw_df.keywords.reset_index().to_json(dump_path, orient="split", index=False)
# Out:
# wiki-pages-text/wiki-001.txt
# wiki-pages-text/wiki-002.txt
# wiki-pages-text/wiki-003.txt
# wiki-pages-text/wiki-004.txt
# wiki-pages-text/wiki-005.txt
# wiki-pages-text/wiki-006.txt
# wiki-pages-text/wiki-007.txt
# wiki-pages-text/wiki-008.txt
# wiki-pages-text/wiki-009.txt
# wiki-pages-text/wiki-010.txt
# wiki-pages-text/wiki-011.txt
# wiki-pages-text/wiki-012.txt
# wiki-pages-text/wiki-013.txt
# wiki-pages-text/wiki-014.txt
# wiki-pages-text/wiki-015.txt
# wiki-pages-text/wiki-016.txt
# wiki-pages-text/wiki-017.txt
# wiki-pages-text/wiki-018.txt
# wiki-pages-text/wiki-019.txt
# wiki-pages-text/wiki-020.txt
# wiki-pages-text/wiki-021.txt
# wiki-pages-text/wiki-022.txt
# wiki-pages-text/wiki-023.txt
# wiki-pages-text/wiki-024.txt
# wiki-pages-text/wiki-025.txt
# wiki-pages-text/wiki-026.txt
# wiki-pages-text/wiki-027.txt
# wiki-pages-text/wiki-028.txt
# wiki-pages-text/wiki-029.txt
# wiki-pages-text/wiki-030.txt
# wiki-pages-text/wiki-031.txt
# wiki-pages-text/wiki-032.txt
# wiki-pages-text/wiki-033.txt
# wiki-pages-text/wiki-034.txt
# wiki-pages-text/wiki-035.txt
# wiki-pages-text/wiki-036.txt
# wiki-pages-text/wiki-037.txt
# wiki-pages-text/wiki-038.txt
# wiki-pages-text/wiki-039.txt
# wiki-pages-text/wiki-040.txt
# wiki-pages-text/wiki-041.txt
# wiki-pages-text/wiki-042.txt
# wiki-pages-text/wiki-043.txt
# wiki-pages-text/wiki-044.txt
# wiki-pages-text/wiki-045.txt
# wiki-pages-text/wiki-046.txt
# wiki-pages-text/wiki-047.txt
# wiki-pages-text/wiki-048.txt
# wiki-pages-text/wiki-049.txt
# wiki-pages-text/wiki-050.txt
# wiki-pages-text/wiki-051.txt
# wiki-pages-text/wiki-052.txt
# wiki-pages-text/wiki-053.txt
# wiki-pages-text/wiki-054.txt
# wiki-pages-text/wiki-055.txt
# wiki-pages-text/wiki-056.txt
# wiki-pages-text/wiki-057.txt
# wiki-pages-text/wiki-058.txt
# wiki-pages-text/wiki-059.txt
# wiki-pages-text/wiki-060.txt
# wiki-pages-text/wiki-061.txt
# wiki-pages-text/wiki-062.txt
# wiki-pages-text/wiki-063.txt
# wiki-pages-text/wiki-064.txt
# wiki-pages-text/wiki-065.txt
# wiki-pages-text/wiki-066.txt
# wiki-pages-text/wiki-067.txt
# wiki-pages-text/wiki-068.txt
# wiki-pages-text/wiki-069.txt
# wiki-pages-text/wiki-070.txt
# wiki-pages-text/wiki-071.txt
# wiki-pages-text/wiki-072.txt
# wiki-pages-text/wiki-073.txt
# wiki-pages-text/wiki-074.txt
# wiki-pages-text/wiki-075.txt
# wiki-pages-text/wiki-076.txt
# wiki-pages-text/wiki-077.txt
# wiki-pages-text/wiki-078.txt
# wiki-pages-text/wiki-079.txt
# wiki-pages-text/wiki-080.txt
# wiki-pages-text/wiki-081.txt
# wiki-pages-text/wiki-082.txt
# wiki-pages-text/wiki-083.txt
# wiki-pages-text/wiki-084.txt
# wiki-pages-text/wiki-085.txt
# wiki-pages-text/wiki-086.txt
# wiki-pages-text/wiki-087.txt
# wiki-pages-text/wiki-088.txt
# wiki-pages-text/wiki-089.txt
# wiki-pages-text/wiki-090.txt
# wiki-pages-text/wiki-091.txt
# wiki-pages-text/wiki-092.txt
# wiki-pages-text/wiki-093.txt
# wiki-pages-text/wiki-094.txt
# wiki-pages-text/wiki-095.txt
# wiki-pages-text/wiki-096.txt
# wiki-pages-text/wiki-097.txt
# wiki-pages-text/wiki-098.txt
# wiki-pages-text/wiki-099.txt
# wiki-pages-text/wiki-100.txt
# wiki-pages-text/wiki-101.txt
# wiki-pages-text/wiki-102.txt
# wiki-pages-text/wiki-103.txt
# wiki-pages-text/wiki-104.txt
# wiki-pages-text/wiki-105.txt
# wiki-pages-text/wiki-106.txt
# wiki-pages-text/wiki-107.txt
# wiki-pages-text/wiki-108.txt
# wiki-pages-text/wiki-109.txt
# CPU times: user 6h 34min 12s, sys: 6min 25s, total: 6h 40min 37s
# Wall time: 6h 41min 25s

# %%
pd.read_json(dump_path, orient='split').head()
# Out:
#      page_id  sentence  \
# 0  Year_book         0
# 1  Year_book         2
# 2  Year_book         4
# 3    Yuneslu         0
# 4    Yuneslu         1
#
#                                                                                                                                                 keywords
# 0                                                                                                                                           [Year, book]
# 1                                                                                         [Yearbook, book, record, highlight, commemorate, year, school]
# 2                                                                                                         [Year, Books, earliest, law, reports, England]
# 3  [Yuneslu, -LRB-, يونسلو, Romanized, Yūneslū, -RRB-, village, Solduz, Rural, District, Central, District, Naqadeh, County, West, Azerbaijan, Provin...
# 4                                                                                                          [2006, census, population, 258, 47, families]

# %%
raw_df.keywords.apply(lambda x: list(nltk.trigrams(x)))
# Out:
# 0                                [(following, football, soccer), (football, soccer, events), (soccer, events, year), (events, year, 1928), (year, 1928, world)]
# 1         [(1986, NBA, Finals), (NBA, Finals, championship), (Finals, championship, round), (championship, round, 1985-86), (round, 1985-86, NBA), (1985-86,...
# 2         [(Eastern, Conference, champion), (Conference, champion, Boston), (champion, Boston, Celtics), (Boston, Celtics, Western), (Celtics, Western, Conf...
# 3                       [(Celtics, Rockets, four), (Rockets, four, games), (four, games, two), (games, two, 16th), (two, 16th, NBA), (16th, NBA, championship)]
# 4                                                     [(championship, Celtics, '), (Celtics, ', last), (', last, 2008), (last, 2008, NBA), (2008, NBA, Finals)]
# 5                                                                                                                  [(Larry, Bird, Finals), (Bird, Finals, MVP)]
# 6         [(note, series, first), (series, first, time), (first, time, NBA), (time, NBA, Finals), (NBA, Finals, branding), (Finals, branding, NBA), (brandin...
# 7                                                     [(2011, series, last), (series, last, time), (last, time, NBA), (time, NBA, Finals), (NBA, Finals, June)]
# 8                                                                       [(game, three, NBA), (three, NBA, Finals), (NBA, Finals, games), (Finals, games, June)]
# 9                                                                    [(following, year, NBA), (year, NBA, Finals), (NBA, Finals, month), (Finals, month, June)]
# 10        [(last, NBA, Finals), (NBA, Finals, series), (Finals, series, game), (series, game, Monday), (game, Monday, 1999), (Monday, 1999, last), (1999, la...
# 11        [(CBS, Sports, Dick), (Sports, Dick, Stockton), (Dick, Stockton, Tom), (Stockton, Tom, Heinsohn), (Tom, Heinsohn, play-by-play), (Heinsohn, play-b...
# 12        [(Brent, Musburger, host), (Musburger, host, Pat), (host, Pat, O'Brien), (Pat, O'Brien, Rockets), (O'Brien, Rockets, '), (Rockets, ', sideline), (...
# 13        [(1901, Villanova, Wildcats), (Villanova, Wildcats, football), (Wildcats, football, team), (football, team, Villanova), (team, Villanova, Universi...
# 14                                                                    [(Wildcats, team, captain), (team, captain, John), (captain, John, J.), (John, J., Egan)]
# 15        [(1992, Northwestern, Wildcats), (Northwestern, Wildcats, team), (Wildcats, team, Northwestern), (team, Northwestern, University), (Northwestern, ...
# 16        [(first, year, head), (year, head, coach), (head, coach, Gary), (coach, Gary, Barnett), (Gary, Barnett, Wildcats), (Barnett, Wildcats, 3-8), (Wild...
# 17        [(team, 's, offensive), ('s, offensive, leaders), (offensive, leaders, Len), (leaders, Len, Williams), (Len, Williams, 2,110), (Williams, 2,110, p...
# 18        [(Gissendaner, Associated, Press), (Associated, Press, first-team), (Press, first-team, wide), (first-team, wide, receiver), (wide, receiver, 1992...
# 19        [(1897, Princeton, Tigers), (Princeton, Tigers, football), (Tigers, football, team), (football, team, Princeton), (team, Princeton, University), (...
# 20                                                                                                                                       [(team, 10-1, record)]
# 21        [(Tigers, first, games), (first, games, combined), (games, combined, score), (combined, score, 339), (score, 339, 0), (339, 0, last), (0, last, ga...
# 22        [(Two, Princeton, players), (Princeton, players, halfback), (players, halfback, Addison), (halfback, Addison, Kelly), (Addison, Kelly, Garrett), (...
# 23                                                                                                                                                           []
# 24        [(di, terra, eighth), (terra, eighth, studio), (eighth, studio, album), (studio, album, Italian), (album, Italian, progressive), (Italian, progres...
# 25           [(entirely, instrumental, work), (instrumental, work, Orchestra), (work, Orchestra, Musicisti), (Orchestra, Musicisti, di), (Musicisti, di, Roma)]
# 26        [(album, title, earth), (title, earth, poem), (earth, poem, Francesco), (poem, Francesco, Di), (Francesco, Di, Giacomo), (Di, Giacomo, song), (Gia...
# 27        [(March, 14, 1968), (14, 1968, home), (1968, home, St.), (home, St., James), (St., James, St.), (James, St., James), (St., James, Canadians), (Jam...
# 28        [(All-Ireland, Senior, Hurling), (Senior, Hurling, Championship), (Hurling, Championship, 1998), (Championship, 1998, sponsorship), (1998, sponsor...
# 29        [(Offaly, championship, Kilkenny), (championship, Kilkenny, 2-16), (Kilkenny, 2-16, 1-13), (2-16, 1-13, final), (1-13, final, Croke), (final, Crok...
# 30        [(1942, Pittsburgh, Steelers), (Pittsburgh, Steelers, season), (Steelers, season, club), (season, club, 's), (club, 's, tenth), ('s, tenth, annive...
# 31        [(team, previous, season), (previous, season, result), (season, result, 1-9-1), (result, 1-9-1, record), (1-9-1, record, 7-4-0), (record, 7-4-0, g...
# 32                                                                                                                [(franchise, 's, first), ('s, first, record)]
# 33                                 [(second, straight, year), (straight, year, team), (year, team, camp), (team, camp, Hershey), (camp, Hershey, Pennsylvania)]
# 34        [(1936, Argentine, Primera), (Argentine, Primera, División), (Primera, División, 45), (División, 45, °), (45, °, season), (°, season, top-flight),...
# 35        [(Two, regular, championships), (regular, championships, year), (championships, year, Copa), (year, Copa, de), (Copa, de, Honor), (de, Honor, San)...
# 36        [(end, season, champions), (season, champions, River), (champions, River, San), (River, San, Lorenzo), (San, Lorenzo, single), (Lorenzo, single, m...
# 37                                                [(River, Plate, match), (Plate, match, additional), (match, additional, league), (additional, league, title)]
# 38        [(1937, New, York), (New, York, Giants), (York, Giants, season), (Giants, season, thirteenth), (season, thirteenth, season), (thirteenth, season, ...
# 39        [(1924, Argentine, Primera), (Argentine, Primera, División), (Primera, División, 33), (División, 33, °), (33, °, season), (°, season, top-flight),...
# 40        [(AFA, season, April), (season, April, 13), (April, 13, January), (13, January, 4), (January, 4, 1925), (4, 1925, AAmF), (1925, AAmF, April), (AAm...
# 41        [(1978, RTHK, Top), (RTHK, Top, 10), (Top, 10, Gold), (10, Gold, Songs), (Gold, Songs, Awards), (Songs, Awards, Chinese), (Awards, Chinese, 1978年度...
# 42        [(Copa, del, Generalísimo), (del, Generalísimo, 1958), (Generalísimo, 1958, 56th), (1958, 56th, staging), (56th, staging, Spanish), (staging, Span...
# 43                                           [(competition, May, 18), (May, 18, 1958), (18, 1958, June), (1958, June, 29), (June, 29, 1958), (29, 1958, final)]
# 44        [(1891, Scottish, Cup), (Scottish, Cup, Final), (Cup, Final, 7), (Final, 7, February), (7, February, 1891), (February, 1891, second), (1891, secon...
# 45                                                                                                                                 [(Hearts, Dumbarton, match)]
# 46        [(Hearts, match, 1-0), (match, 1-0, thanks), (1-0, thanks, 15th-minute), (thanks, 15th-minute, goal), (15th-minute, goal, Willie), (goal, Willie, ...
# 47        [(1934, Rose, Bowl), (Rose, Bowl, January), (Bowl, January, 1), (January, 1, 1934), (1, 1934, American), (1934, American, football), (American, fo...
# 48                                                                                                                     [(20th, Rose, Bowl), (Rose, Bowl, Game)]
# 49                                           [(Columbia, Lions, Stanford), (Lions, Stanford, Indians), (Stanford, Indians, Cardinal), (Indians, Cardinal, 7-0)]
#                                                                                   ...
# 170496                                                                                    [(underlying, meanings, ***), (meanings, ***, raw), (***, raw, text)]
# 170497                                                                                                                                                       []
# 170498    [(One, reviewer, ***), (reviewer, ***, passage), (***, passage, mood), (passage, mood, reader), (mood, reader, archetypal), (reader, archetypal, w...
# 170499                                                                                                                                                       []
# 170500                                                                                                      [(novel, PROLOGUE, title), (PROLOGUE, title, page)]
# 170501                                   [(other, title, page), (title, page, novel), (page, novel, entire), (novel, entire, novel), (entire, novel, prologue)]
# 170502    [(short, chapter, instructions), (chapter, instructions, assembly), (instructions, assembly, book), (assembly, book, 's), (book, 's, packets), ('s...
# 170503                                                                                                                                                       []
# 170504                                    [(end, alternative, plot), (alternative, plot, lines), (plot, lines, next), (lines, next, time), (next, time, story)]
# 170505                                                                                                                                                       []
# 170506    [(1974, NCAA, Division), (NCAA, Division, II), (Division, II, Lacrosse), (II, Lacrosse, Championship), (Lacrosse, Championship, first), (Champions...
# 170507    [(year, 's, championship), ('s, championship, game), (championship, game, SUNY), (game, SUNY, Cortland), (SUNY, Cortland, Stadium), (Cortland, Sta...
# 170508    [(Three, editions, NCAA), (editions, NCAA, Division), (NCAA, Division, Lacrosse), (Division, Lacrosse, Championship), (Lacrosse, Championship, sep...
# 170509    [(addition, two, USILA), (two, USILA, small), (USILA, small, college), (small, college, tournaments), (college, tournaments, 1972), (tournaments, ...
# 170510    [(Towson, State, Hobart), (State, Hobart, final), (Hobart, final, 18), (final, 18, −), (18, −, 17), (−, 17, double), (17, double, overtime), (doub...
# 170511                                                                                                                                                       []
# 170512                                                                                                                                                       []
# 170513                                                                                                                                  [(other, events, 1903)]
# 170514                                                                                                                                                       []
# 170515                                                                                                                                   [(list, years, crime)]
# 170516    [(1972, USC, Trojans), (USC, Trojans, football), (Trojans, football, team), (football, team, University), (team, University, Southern), (Universit...
# 170517    [(Carlos, Palanca, Memorial), (Palanca, Memorial, Awards), (Memorial, Awards, Literature), (Awards, Literature, winners), (Literature, winners, ye...
# 170518                                                                                                                                        [(__, NOTOC, __)]
# 170519     [(101st, Panzer, Brigade), (Panzer, Brigade, Panzer), (Brigade, Panzer, Brigade), (Panzer, Brigade, World), (Brigade, World, War), (World, War, II)]
# 170520             [(1930, Staten, Island), (Staten, Island, Stapletons), (Island, Stapletons, season), (Stapletons, season, second), (season, second, league)]
# 170521                                                       [(team, previous, output), (previous, output, 3-4-3), (output, 3-4-3, five), (3-4-3, five, games)]
# 170522                                                                                                                                                       []
# 170523    [(1966, Gator, Bowl), (Gator, Bowl, college), (Bowl, college, football), (college, football, postseason), (football, postseason, bowl), (postseaso...
# 170524    [(1933, Grand, National), (Grand, National, 92nd), (National, 92nd, renewal), (92nd, renewal, world-famous), (renewal, world-famous, Grand), (worl...
# 170525    [(steeplechase, Kellsboro, '), (Kellsboro, ', Jack), (', Jack, 25/1), (Jack, 25/1, shot), (25/1, shot, ridden), (shot, ridden, jockey), (ridden, j...
# 170526    [(seven-year-old, horse, Ivor), (horse, Ivor, Anthony), (Ivor, Anthony, American), (Anthony, American, owner), (American, owner, F.), (owner, F., ...
# 170527                                                [(Anthonylater, National, winner), (National, winner, Royal), (winner, Royal, Mail), (Royal, Mail, 1937)]
# 170528                            [(second, place, True), (place, True, Slater), (True, Slater, third), (Slater, third, Delaneige), (third, Delaneige, fourth)]
# 170529                                                                                                                         [(Thirty-four, horses, stables)]
# 170530    [(1994, PBA, All-Filipino), (PBA, All-Filipino, Cup), (All-Filipino, Cup, Finals), (Cup, Finals, best-of-7), (Finals, best-of-7, championship), (b...
# 170531    [(San, Miguel, Beermen), (Miguel, Beermen, Coney), (Beermen, Coney, Island), (Coney, Island, Ice), (Island, Ice, Cream), (Ice, Cream, Stars), (Cre...
# 170532    [(trip, Hiroshima, Japan), (Hiroshima, Japan, Asian), (Japan, Asian, Games), (Asian, Games, September), (Games, September, stake), (September, sta...
# 170533    [(San, Miguel, Beermen), (Miguel, Beermen, 11th), (Beermen, 11th, league), (11th, league, crown), (league, crown, right), (crown, right, champion)...
# 170534                                              [(1865, sports, year), (sports, year, 's), (year, 's, events), ('s, events, world), (events, world, sport)]
# 170535             [(1993, Ghana, details), (Ghana, details, events), (details, events, note), (events, note, Ghana), (note, Ghana, year), (Ghana, year, 1993)]
# 170536    [(1996, Detroit, Tigers), (Detroit, Tigers, record), (Tigers, record, 53-109), (record, 53-109, third), (53-109, third, worst), (third, worst, per...
# 170537    [(number, capable, batters), (capable, batters, Cecil), (batters, Cecil, Fielder), (Cecil, Fielder, Tony), (Fielder, Tony, Clark), (Tony, Clark, B...
# 170538                                        [(1996, Tigers, pitching), (Tigers, pitching, opponents), (pitching, opponents, 1,103), (opponents, 1,103, runs)]
# 170539    [(team, American, League), (American, League, history), (League, history, one), (history, one, major), (one, major, league), (major, league, histo...
# 170540                                                                                                [(pitcher, team, more), (team, more, 7), (more, 7, wins)]
# 170541    [(Tigers, more, unwanted), (more, unwanted, history), (unwanted, history, 12-0), (history, 12-0, Cleveland), (12-0, Cleveland, Indians), (Clevelan...
# 170542    [(Willoughby, Hamilton, Harry), (Hamilton, Harry, S.), (Harry, S., Barlow), (S., Barlow, 2-6), (Barlow, 2-6, 6-4), (2-6, 6-4, 6-4), (6-4, 6-4, 4-6...
# 170543                                                            [(Events, year, 1916), (year, 1916, Taiwan), (1916, Taiwan, Empire), (Taiwan, Empire, Japan)]
# 170544    [(1956, SANFL, Grand), (SANFL, Grand, Final), (Grand, Final, Australian), (Final, Australian, rules), (Australian, rules, football), (rules, footb...
# 170545                                                                                                                                         [(beat, 81, 65)]
# Name: keywords, Length: 170546, dtype: object
